# %% [markdown]
# <a href="https://colab.research.google.com/github/Jumponpatha/portfolio/blob/main/MiniProject_DA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Netflix Data Analysis Project**

# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd

# %%
df = pd.read_csv('netflix_titles.csv')
df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
df.shape
# Out:
# (6234, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
df.nunique()
# Out:
# show_id         6234
# type               2
# title           6172
# director        3301
# cast            5469
# country          554
# date_added      1524
# release_year      72
# rating            14
# duration         201
# listed_in        461
# description     6226
# dtype: int64

# %% [markdown]
# ## Data Cleansing

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.drop_duplicates()
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
df = df.drop(columns=['description'])
df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
df = df.dropna()
df
# Out:
#        show_id     type                                    title  \
# 0     81145628    Movie  Norm of the North: King Sized Adventure
# 4     80125979    Movie                             #realityhigh
# 6     70304989    Movie                                 Automata
# 7     80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 9     70304990    Movie                              Good People
# ...        ...      ...                                      ...
# 6142  80063224  TV Show            The Great British Baking Show
# 6158  80164216  TV Show  Miraculous: Tales of Ladybug & Cat Noir
# 6167  80115328  TV Show                             Sacred Games
# 6182  80176842  TV Show                         Men on a Mission
# 6213  80126599  TV Show                         Leyla and Mecnun
#
#                                   director  \
# 0                 Richard Finn, Tim Maltby
# 4                         Fernando Lebrija
# 6                              Gabe Ibáñez
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df['listed_in'].unique()
# Out:
# array(['Children & Family Movies, Comedies', 'Comedies',
#        'International Movies, Sci-Fi & Fantasy, Thrillers',
#        'Stand-Up Comedy', 'Action & Adventure, Thrillers',
#        'Action & Adventure, Dramas, International Movies',
#        'Cult Movies, Dramas, Independent Movies',
#        'Comedies, Independent Movies, Romantic Movies',
#        'Action & Adventure, Comedies, International Movies',
#        'Horror Movies, Thrillers', 'Dramas, Independent Movies',
#        'Dramas, Independent Movies, Romantic Movies',
#        'Horror Movies, International Movies',
#        'Children & Family Movies, Comedies, Sci-Fi & Fantasy',
#        'Comedies, Romantic Movies',
#        'Dramas, International Movies, Thrillers',
#        'Dramas, Independent Movies, International Movies',
#        'Comedies, International Movies',
#        'Action & Adventure, Comedies, Independent Movies',
#        'Comedies, Dramas, International Movies', 'Documentaries',
# ...

# %%
df['date_added']
# Out:
# 0       September 9, 2019
# 4       September 8, 2017
# 6       September 8, 2017
# 7       September 8, 2017
# 9       September 8, 2017
#               ...
# 6142      August 30, 2019
# 6158       August 2, 2019
# 6167      August 15, 2019
# 6182        April 9, 2019
# 6213       April 15, 2017
# Name: date_added, Length: 3774, dtype: object

# %%
a = df['date_added'].dropna()
a
# Out:
# 0       September 9, 2019
# 4       September 8, 2017
# 6       September 8, 2017
# 7       September 8, 2017
# 9       September 8, 2017
#               ...
# 6142      August 30, 2019
# 6158       August 2, 2019
# 6167      August 15, 2019
# 6182        April 9, 2019
# 6213       April 15, 2017
# Name: date_added, Length: 3774, dtype: object

# %%
df['listed_in'].nunique()
# Out:
# 296

# %% [markdown]
# ### Top 10 country in Netflix users

# %%
pd.DataFrame(df.groupby('country')['show_id'].nunique().sort_values(ascending=False).head(10))
# Out:
#                 show_id
# country
# United States      1323
# India               707
# United Kingdom      152
# Canada               78
# Spain                72
# Turkey               60
# Japan                54
# Mexico               51
# Hong Kong            48
# France               46

# %% [markdown]
# ### Count of Netflix titles type (Movie, TV show)

# %%
type = df.groupby(['type'])['type'].count()
pd.DataFrame(type)
# Out:
#          type
# type
# Movie    3678
# TV Show    96

# %% [markdown]
# ### Count of titles each rating by descending order

# %%
df['rating'].nunique()
# Out:
# 14

# %%
rating_pivot = df.pivot_table(index='rating', values=['title'], aggfunc='nunique')
rating_pivot = rating_pivot.sort_values(by=['title'], ascending=False)
rating_pivot
# Out:
#           title
# rating
# TV-MA      1183
# TV-14       916
# R           500
# TV-PG       358
# PG-13       278
# PG          176
# NR          175
# TV-G         54
# TV-Y7        48
# G            35
# TV-Y         24
# TV-Y7-FV     11
# UR            7
# NC-17         1

# %%
rating_pivot.plot.bar(color='green')
plt.xlabel('Rating')
plt.ylabel('Number of title in each rating')
plt.title('Table show number rating each titles')
plt.show()

# %% [markdown]
# ### Table of Korean Netflix titles

# %%
south_korea = df[df['country']=='South Korea']
south_korea.head()
# Out:
#       show_id     type                         title       director  \
# 71   80187061    Movie                     The Mayor     Park In-je
# 474  81166978  TV Show            Bring It On, Ghost  Park Joon-hwa
# 631  80239666    Movie      Illang: The Wolf Brigade   Kim Jee-woon
# 668  81053240    Movie  Park Na-rae: Glamour Warning  Kim Joo-hyung
# 787  81166946  TV Show            Cheese in the Trap  Lee Yoon-jung
#
#                                                   cast      country  \
# 71   Min-sik Choi, Do-won Kwak, Eun-kyung Shim, So-...  South Korea
# 474  Taecyeon, Kim So-hyun, Kwon Yul, Kim Sang-ho, ...  South Korea
# 631  Gang Dong-won, Han Hyo-joo, Jung Woo-sung, Kim...  South Korea
# 668                                        Park Na-rae  South Korea
# 787  Park Hae-Jin, Kim Go-eun, Seo Kang-jun, Lee Su...  South Korea
#
#              date_added  release_year rating  duration  \
# 71   September 30, 2017          2017  TV-MA   130 min
# ...

# %% [markdown]
# ### Table of Netfilx titles after 2017

# %%
after_2017 = df[df['release_year'] > 2017]
after_2017.head()
# Out:
#      show_id   type                                     title  \
# 0   81145628  Movie   Norm of the North: King Sized Adventure
# 30  80988892  Movie                                  Next Gen
# 31  80239639  Movie                 Sierra Burgess Is A Loser
# 32  80159586  Movie  The Most Assassinated Woman in the World
# 35  81154455  Movie                                Article 15
#
#                        director  \
# 0      Richard Finn, Tim Maltby
# 30  Kevin R. Adams, Joe Ksander
# 31                  Ian Samuels
# 32               Franck Ribière
# 35                Anubhav Sinha
#
#                                                  cast  \
# 0   Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 30  John Krasinski, Charlyne Yi, Jason Sudeikis, M...
# 31  Shannon Purser, Kristine Froseth, RJ Cyler, No...
# 32  Anna Mouglalis, Niels Schneider, André Wilms, ...
# 35  Ayushmann Khurrana, Nassar, Manoj Pahwa, Kumud...
#
# ...

# %% [markdown]
# ### Table of Korean Netflix titles after 2017

# %%
south_korea[south_korea['release_year']>2017]
# Out:
#        show_id     type                           title  \
# 631   80239666    Movie        Illang: The Wolf Brigade
# 668   81053240    Movie    Park Na-rae: Glamour Warning
# 1037  81165326    Movie                Tune in for Love
# 1618  81010699    Movie         Svaha: The Sixth Finger
# 1628  80244640    Movie     Jo Pil-ho: The Dawning Rage
# 1644  81034931    Movie                         Rampant
# 2232  80226234    Movie                      Steel Rain
# 2770  80991107  TV Show                    Mr. Sunshine
# 3258  81026705    Movie                    High Society
# 3396  81000511    Movie                        Revenger
# 3874  80236133    Movie                   The Drug King
# 4953  80223582    Movie  Yoo Byung Jae: Discomfort Zone
# 5256  81015498    Movie                         Burning
# 5307  80226424    Movie                   Psychokinesis
# 5460  81044884  TV Show                         Persona
# 6182  80176842  TV Show                Men on a Mission
#
# ...

# %%
after2017_korea = south_korea.merge(after_2017, how='inner', left_on='show_id', right_on='show_id')
after2017_korea.head()
# Out:
#     show_id type_x                       title_x      director_x  \
# 0  80239666  Movie      Illang: The Wolf Brigade    Kim Jee-woon
# 1  81053240  Movie  Park Na-rae: Glamour Warning   Kim Joo-hyung
# 2  81165326  Movie              Tune in for Love     Jung Ji-woo
# 3  81010699  Movie       Svaha: The Sixth Finger   Jang Jae-hyun
# 4  80244640  Movie   Jo Pil-ho: The Dawning Rage  Lee Jeong-beom
#
#                                               cast_x    country_x  \
# 0  Gang Dong-won, Han Hyo-joo, Jung Woo-sung, Kim...  South Korea
# 1                                        Park Na-rae  South Korea
# 2  Kim Go-eun, Jung Hae-in, Park Hae-joon, Kim Gu...  South Korea
# 3  Lee Jung-jae, Park Jung-min, Lee Jae-in, Yoo J...  South Korea
# 4  Lee Sun-kyun, Jeon So-nee, Park Hae-joon, Song...  South Korea
#
#        date_added_x  release_year_x rating_x duration_x  ... type_y  \
# 0  October 19, 2018            2018    TV-MA    140 min  ...  Movie
# ...

# %%
list(after2017_korea)
# Out:
# ['show_id',
#  'type_x',
#  'title_x',
#  'director_x',
#  'cast_x',
#  'country_x',
#  'date_added_x',
#  'release_year_x',
#  'rating_x',
#  'duration_x',
#  'listed_in_x',
#  'type_y',
#  'title_y',
#  'director_y',
#  'cast_y',
#  'country_y',
#  'date_added_y',
#  'release_year_y',
#  'rating_y',
#  'duration_y',
#  'listed_in_y']

# %%
after2017_korea[['show_id',
 'type_x',
 'title_x',
 'director_x',
 'cast_x',
 'country_x',
 'date_added_x',
 'release_year_x',
 'rating_x',
 'duration_x',
 'listed_in_x']].head()
# Out:
#     show_id type_x                       title_x      director_x  \
# 0  80239666  Movie      Illang: The Wolf Brigade    Kim Jee-woon
# 1  81053240  Movie  Park Na-rae: Glamour Warning   Kim Joo-hyung
# 2  81165326  Movie              Tune in for Love     Jung Ji-woo
# 3  81010699  Movie       Svaha: The Sixth Finger   Jang Jae-hyun
# 4  80244640  Movie   Jo Pil-ho: The Dawning Rage  Lee Jeong-beom
#
#                                               cast_x    country_x  \
# 0  Gang Dong-won, Han Hyo-joo, Jung Woo-sung, Kim...  South Korea
# 1                                        Park Na-rae  South Korea
# 2  Kim Go-eun, Jung Hae-in, Park Hae-joon, Kim Gu...  South Korea
# 3  Lee Jung-jae, Park Jung-min, Lee Jae-in, Yoo J...  South Korea
# 4  Lee Sun-kyun, Jeon So-nee, Park Hae-joon, Song...  South Korea
#
#        date_added_x  release_year_x rating_x duration_x  \
# 0  October 19, 2018            2018    TV-MA    140 min
# 1  October 16, 2019            2019    TV-MA     63 min
# ...

# %% [markdown]
# ### Date add of Netflix titles

# %%
date = df[['title','date_added']].dropna()
date
# Out:
#                                         title         date_added
# 0     Norm of the North: King Sized Adventure  September 9, 2019
# 4                                #realityhigh  September 8, 2017
# 6                                    Automata  September 8, 2017
# 7          Fabrizio Copano: Solo pienso en mi  September 8, 2017
# 9                                 Good People  September 8, 2017
# ...                                       ...                ...
# 6142            The Great British Baking Show    August 30, 2019
# 6158  Miraculous: Tales of Ladybug & Cat Noir     August 2, 2019
# 6167                             Sacred Games    August 15, 2019
# 6182                         Men on a Mission      April 9, 2019
# 6213                         Leyla and Mecnun     April 15, 2017
#
# [3774 rows x 2 columns]

# %% [markdown]
# ### Titles added on August

# %%
sep = date[date['date_added'].str.contains('August')]
sep
# Out:
#                                         title        date_added
# 4724                  Jaoon Kahan Bata Ae Dil    August 9, 2019
# 4725        Rocko's Modern Life: Static Cling    August 9, 2019
# 4731                                  Perdida    August 9, 2018
# 4733                         Black Site Delta    August 9, 2017
# 4736     Judy Moody and the Not Bummer Summer    August 8, 2019
# ...                                       ...               ...
# 5173              Real Crime: Diamond Geezers    August 1, 2016
# 6134                          Abnormal Summit    August 4, 2017
# 6142            The Great British Baking Show   August 30, 2019
# 6158  Miraculous: Tales of Ladybug & Cat Noir    August 2, 2019
# 6167                             Sacred Games   August 15, 2019
#
# [298 rows x 2 columns]
