# %% [markdown]
# # **Final Project Data Model(CPE232)**

# %% [markdown]
# ## **Project** : Mercedes Benz Price Prediction

# %% [markdown]
# Member Group
#
# *   Ms. Sarinyapak Namwong 			          64070503403
# *   Mr. Jumponpatha Chaimongkonrojna 		  64070503408
# *   Mr. Phanasorn Srisayam 			          64070503436
# *   Mr. Warut Wannasert		                64070503448
# *   Mr. Veerapat Toonhirunkorn 			      64070503474
#
# SUBMITTED TO
# Prof. SANTITHAM PROM-ON

# %% [markdown]
# Import library & Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
mercedes = pd.read_csv('mercedes-price.csv')

# %% [markdown]
# Preview Data

# %%
mercedes
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# 3             4.0
# 4             4.0
# ...           ...
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9
#
# [13119 rows x 9 columns]

# %% [markdown]
# # **Cleaning Data**

# %% [markdown]
# Check Data type info

# %%
mercedes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13119 entries, 0 to 13118
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         13119 non-null  object
#  1   year          13119 non-null  int64
#  2   price         13119 non-null  int64
#  3   transmission  13119 non-null  object
#  4   mileage       13119 non-null  int64
#  5   fuelType      13119 non-null  object
#  6   tax           13119 non-null  int64
#  7   mpg           13119 non-null  float64
#  8   engineSize    13119 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 922.6+ KB

# %% [markdown]
# Check Null value

# %%
mercedes.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %% [markdown]
# Shape function

# %%
mercedes.shape
# Out:
# (13119, 9)

# %% [markdown]
# Preprocess data

# %%
mercedes.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %% [markdown]
# Checking frequency of 'transmission'

# %%
pd.crosstab(mercedes['transmission'], columns='Count')
# Out:
# col_0         Count
# transmission
# Automatic      4825
# Manual         1444
# Other             2
# Semi-Auto      6848

# %% [markdown]
# * Note that, from column of transmission which contain Automatic, Manual, Semi-Auto and Other would see a 'Other' column were have only 2 data which could cause outlier.

# %% [markdown]
# Cleansing data by deleting transmission type 'Other'

# %%
cleansing1 = mercedes[mercedes['transmission'] != 'Other'].dropna()
cleansing1
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# 3             4.0
# 4             4.0
# ...           ...
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9
#
# [13117 rows x 9 columns]

# %% [markdown]
# Showing 'transmission' data which had cleansed

# %%
sns.countplot(data=cleansing1, y='transmission')
# Out:
# <Axes: xlabel='count', ylabel='transmission'>

# %% [markdown]
# Checking frequency of 'fuelType'

# %%
pd.crosstab(mercedes['fuelType'], columns='Count')
# Out:
# col_0     Count
# fuelType
# Diesel     9187
# Hybrid      173
# Other         7
# Petrol     3752

# %% [markdown]
# * Note that, from column of fuelType which contain Automatic, Manual, Semi-Auto and Other would see a 'Other' column were have only 2 data which could cause outlier.

# %% [markdown]
# Cleansing data by deleting fuelType type 'Other'

# %%
cleansing2 = cleansing1[cleansing1['fuelType'] != 'Other'].dropna()
cleansing2
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# 3             4.0
# 4             4.0
# ...           ...
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9
#
# [13111 rows x 9 columns]

# %% [markdown]
# Showing 'transmission' data which had cleansed

# %%
sns.countplot(data=cleansing2, y='fuelType')
# Out:
# <Axes: xlabel='count', ylabel='fuelType'>

# %% [markdown]
# Describing Data

# %%
mercedes2 = cleansing2.loc[:,'price':'engineSize']
mercedes2.describe()
# Out:
#                price        mileage           tax           mpg    engineSize
# count   13111.000000   13111.000000  13111.000000  13111.000000  13111.000000
# mean    24700.935016   21935.920067    130.020212     55.117443      2.071642
# std     11843.607522   21169.443845     65.230548     15.094034      0.572256
# min       650.000000       1.000000      0.000000      1.100000      0.000000
# 25%     17450.000000    6090.000000    125.000000     45.600000      1.800000
# 50%     22480.000000   15181.000000    145.000000     56.500000      2.000000
# 75%     28980.000000   31733.000000    145.000000     64.200000      2.100000
# max    159999.000000  259000.000000    580.000000    217.300000      6.200000

# %% [markdown]
# Showing 'fuelType' data which had cleansed

# %%
sns.scatterplot(data=cleansing2, x="year", y = "price",hue="transmission")
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %% [markdown]
# * Find Outlier, so we should cleansing again by delete 1970 data.

# %%
mercedes2 = cleansing2[cleansing2['year'] != 1970].dropna()
mercedes2
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# 3             4.0
# 4             4.0
# ...           ...
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9
#
# [13110 rows x 9 columns]

# %% [markdown]
# Number of sold car model each year

# %%
sns.scatterplot(data=mercedes2, x="year", y = "price",hue="transmission")
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
mercedes2.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13110.000000   13110.000000   13110.000000  13110.000000  13110.000000
# mean    2017.300381   24700.912281   21936.525400    130.006865     55.118658
# std        2.186392   11844.058963   21170.137793     65.215130     15.093970
# min     1997.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6087.000000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15181.500000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31734.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13110.000000
# mean       2.071800
# std        0.571991
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %% [markdown]
# Show a price each transmission and each year

# %%
sns.lineplot(data=mercedes2, x="year", y="price", hue="transmission")
# Out:
# c:\Users\acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='year', ylabel='price'>

# %% [markdown]
# Boxplot of price

# %%
mercedes2.boxplot(column='price', color='orange')
# Out:
# <Axes: >

# %% [markdown]
# Histrogram of mercedes model

# %%
ax = sns.histplot(data=mercedes2, x="model", kde=True, color='orange')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()
# Out:
# c:\Users\acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\acer\AppData\Local\Temp\ipykernel_14552\3866149668.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %% [markdown]
# Histrogram of price

# %%
sns.histplot(data=mercedes2, x="price", kde=True, color='orange')
# Out:
# c:\Users\acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# Relation graph between model and price.

# %%
model_mileage = mercedes2.groupby('model')['price'].mean().sort_values()
plt.figure(figsize=(15,5))
pal = sns.color_palette("Oranges", len(model_mileage))
sns.barplot(x=model_mileage.index , y=model_mileage , palette=pal)

plt.xticks(rotation=70)

plt.title('Model vs Price graph')

plt.savefig("model_mileage.png")

# %% [markdown]
# Preprocessing

# %% [markdown]
# ---

# %%
#Show the non-numerical columns
non_numerical_cols = mercedes2.select_dtypes(exclude='number').columns.tolist()
non_numerical_cols
# Out:
# ['model', 'transmission', 'fuelType']

# %%
# Using LabelEncoder

from sklearn.preprocessing import LabelEncoder
encoding = LabelEncoder()
new_df = mercedes2.copy()

#Label Encoding
for cols in non_numerical_cols: #Use For-loop
    new_df[cols] = encoding.fit_transform(mercedes2[cols])

# %%
new_df
# Out:
#        model  year  price  transmission  mileage  fuelType  tax   mpg  \
# 0         20  2005   5200             0    63000         2  325  32.1
# 1         18  2017  34948             0    27000         1   20  61.4
# 2         19  2016  49948             0     6200         2  555  28.0
# 3          9  2016  61948             0    16000         2  325  30.4
# 4          9  2016  73948             0     4000         2  325  30.1
# ...      ...   ...    ...           ...      ...       ...  ...   ...
# 13114      2  2020  35999             0      500         0  145  55.4
# 13115      1  2020  24699             0     2500         0  145  55.4
# 13116     13  2019  30999             0    11612         0  145  41.5
# 13117      7  2019  37990             0     2426         0  145  45.6
# 13118     18  2019  54999             0     2075         0  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# 3             4.0
# 4             4.0
# ...           ...
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9
#
# [13110 rows x 9 columns]

# %% [markdown]
# Correlation

# %%
new_df.corr()
# Out:
#                  model      year     price  transmission   mileage  fuelType  \
# model         1.000000 -0.053210  0.332791     -0.034892 -0.005171 -0.167307
# year         -0.053210  1.000000  0.529856      0.219196 -0.751821  0.134057
# price         0.332791  0.529856  1.000000      0.111990 -0.537120  0.188709
# transmission -0.034892  0.219196  0.111990      1.000000 -0.206458  0.037069
# mileage      -0.005171 -0.751821 -0.537120     -0.206458  1.000000 -0.212759
# fuelType     -0.167307  0.134057  0.188709      0.037069 -0.212759  1.000000
# tax           0.306189  0.016777  0.268688     -0.019262 -0.159173  0.258183
# mpg          -0.277220 -0.099067 -0.442304     -0.009269  0.202571 -0.465442
# engineSize    0.432413 -0.150917  0.516591     -0.052261  0.063691 -0.047005
#
#                    tax       mpg  engineSize
# model         0.306189 -0.277220    0.432413
# year          0.016777 -0.099067   -0.150917
# price         0.268688 -0.442304    0.516591
# transmission -0.019262 -0.009269   -0.052261
# mileage      -0.159173  0.202571    0.063691
# fuelType      0.258183 -0.465442   -0.047005
# tax           1.000000 -0.515186    0.339955
# mpg          -0.515186  1.000000   -0.343336
# engineSize    0.339955 -0.343336    1.000000

# %% [markdown]
# Correlation Heatmap

# %%
#sns.set(font_scale=0.8)
sns.heatmap(new_df.corr(), annot=True)
plt.show()

# %% [markdown]
# * price vs. year
# * price vs. engineSize
# * price vs. mileage
# * price vs. mpg

# %% [markdown]
# **Modeling**

# %%
from statsmodels.formula.api import ols

model = ols('price ~ year + model + mileage',mercedes2, missing='drop').fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.584
# Model:                            OLS   Adj. R-squared:                  0.584
# Method:                 Least Squares   F-statistic:                     657.1
# Date:                Wed, 24 Apr 2024   Prob (F-statistic):               0.00
# Time:                        15:32:40   Log-Likelihood:            -1.3581e+05
# No. Observations:               13110   AIC:                         2.717e+05
# Df Residuals:                   13081   BIC:                         2.719e+05
# Df Model:                          28
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept           -3.526e+06   9.99e+04    -35.280      0.000   -3.72e+06   -3.33e+06
# model[T. B Class]   -1934.0683    349.020     -5.541      0.000   -2618.199   -1249.938
# model[T. C Class]    4045.4522    196.084     20.631      0.000    3661.099    4429.805
# model[T. CL Class]   2958.9588    370.586      7.985      0.000    2232.555    3685.362
# model[T. CLA Class]  3071.7647    838.476      3.664      0.000    1428.231    4715.299
# model[T. CLC Class]  4374.3458   4423.257      0.989      0.323   -4295.880     1.3e+04
# model[T. CLK]        2.173e+04   2929.760      7.418      0.000     1.6e+04    2.75e+04
# model[T. CLS Class]  9508.2015    519.746     18.294      0.000    8489.424    1.05e+04
# model[T. E Class]    6387.2715    229.843     27.790      0.000    5936.746    6837.797
# model[T. G Class]    7.961e+04   1979.464     40.219      0.000    7.57e+04    8.35e+04
# model[T. GL Class]   6627.7082    713.375      9.291      0.000    5229.390    8026.026
# model[T. GLA Class]  1407.0666    303.226      4.640      0.000     812.699    2001.434
# model[T. GLB Class]  1.013e+04   1762.041      5.748      0.000    6673.581    1.36e+04
# model[T. GLC Class]   1.12e+04    290.095     38.598      0.000    1.06e+04    1.18e+04
# model[T. GLE Class]  1.922e+04    387.228     49.642      0.000    1.85e+04       2e+04
# model[T. GLS Class]  2.587e+04    901.382     28.696      0.000    2.41e+04    2.76e+04
# model[T. M Class]    1.152e+04    891.037     12.933      0.000    9777.475    1.33e+04
# model[T. R Class]    1.191e+04   5414.372      2.199      0.028    1294.861    2.25e+04
# model[T. S Class]    2.653e+04    566.818     46.808      0.000    2.54e+04    2.76e+04
# model[T. SL CLASS]   1.122e+04    499.670     22.464      0.000    1.02e+04    1.22e+04
# model[T. SLK]        7363.3553    841.464      8.751      0.000    5713.963    9012.747
# model[T. V Class]    1.071e+04    552.951     19.371      0.000    9627.503    1.18e+04
# model[T. X-CLASS]    5774.2202    858.513      6.726      0.000    4091.409    7457.031
# model[T.180]         -145.0462   7645.552     -0.019      0.985   -1.51e+04    1.48e+04
# model[T.200]        -2338.7692   7644.663     -0.306      0.760   -1.73e+04    1.26e+04
# model[T.220]        -2684.9896   7644.730     -0.351      0.725   -1.77e+04    1.23e+04
# model[T.230]         1.462e+04   7652.430      1.910      0.056    -384.699    2.96e+04
# year                 1759.1944     49.500     35.539      0.000    1662.167    1856.222
# mileage                -0.1597      0.005    -32.697      0.000      -0.169      -0.150
# ==============================================================================
# Omnibus:                    13355.644   Durbin-Watson:                   1.713
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1389613.293
# Skew:                           4.864   Prob(JB):                         0.00
# Kurtosis:                      52.490   Cond. No.                     4.57e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.57e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
res = model.predict(mercedes2)
res
# Out:
# 0        -1319.685505
# 1        44708.037036
# 2        30963.314988
# 3        97786.336973
# 4        99702.669125
#              ...
# 13114    31731.223619
# 13115    25432.314421
# 13116    35349.176260
# 13117    35127.207280
# 13118    52206.807356
# Length: 13110, dtype: float64

# %% [markdown]
# Distribution between Residual and Predicted plot

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.set(title="Distribution between Residual and Predicited plot", xlabel="Residual", ylabel="Predicted Plot")
sns.scatterplot(x=model.resid, y=res, color='orange')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_14552\1528868892.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
mercedes_num = mercedes2.select_dtypes('number')

mercedes_object = mercedes2.select_dtypes('object')

mercedes_object1 = pd.get_dummies(mercedes_object, drop_first=True, columns=(['transmission','fuelType','model']))
#mercedes_object1 = pd.get_dummies(mercedes_object, drop_first=True)

mercedes_prep = pd.concat([mercedes_num,mercedes_object1], axis=1)
mercedes_prep
# Out:
#        year  price  mileage  tax   mpg  engineSize  transmission_Manual  \
# 0      2005   5200    63000  325  32.1         1.8                False
# 1      2017  34948    27000   20  61.4         2.1                False
# 2      2016  49948     6200  555  28.0         5.5                False
# 3      2016  61948    16000  325  30.4         4.0                False
# 4      2016  73948     4000  325  30.1         4.0                False
# ...     ...    ...      ...  ...   ...         ...                  ...
# 13114  2020  35999      500  145  55.4         2.0                False
# 13115  2020  24699     2500  145  55.4         2.0                False
# 13116  2019  30999    11612  145  41.5         2.1                False
# 13117  2019  37990     2426  145  45.6         2.0                False
# 13118  2019  54999     2075  145  52.3         2.9                False
#
#        transmission_Semi-Auto  fuelType_Hybrid  fuelType_Petrol  ...  \
# 0                       False            False             True  ...
# 1                       False             True            False  ...
# 2                       False            False             True  ...
# 3                       False            False             True  ...
# 4                       False            False             True  ...
# ...                       ...              ...              ...  ...
# 13114                   False            False            False  ...
# 13115                   False            False            False  ...
# 13116                   False            False            False  ...
# 13117                   False            False            False  ...
# 13118                   False            False            False  ...
#
#        model_ R Class  model_ S Class  model_ SL CLASS  model_ SLK  \
# 0               False           False            False        True
# 1               False            True            False       False
# 2               False           False             True       False
# 3               False           False            False       False
# 4               False           False            False       False
# ...               ...             ...              ...         ...
# 13114           False           False            False       False
# 13115           False           False            False       False
# 13116           False           False            False       False
# 13117           False           False            False       False
# 13118           False            True            False       False
#
#        model_ V Class  model_ X-CLASS  model_180  model_200  model_220  \
# 0               False           False      False      False      False
# 1               False           False      False      False      False
# 2               False           False      False      False      False
# 3               False           False      False      False      False
# 4               False           False      False      False      False
# ...               ...             ...        ...        ...        ...
# 13114           False           False      False      False      False
# 13115           False           False      False      False      False
# 13116           False           False      False      False      False
# 13117           False           False      False      False      False
# 13118           False           False      False      False      False
#
#        model_230
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 13114      False
# 13115      False
# 13116      False
# 13117      False
# 13118      False
#
# [13110 rows x 36 columns]

# %% [markdown]
# Linear Regression

# %%
from sklearn.model_selection import train_test_split

mercedes_train, mercedes_test = train_test_split(mercedes_prep, train_size = 0.7)

# %%
mercedes_train.shape
# Out:
# (9177, 36)

# %%
mercedes_test.shape
# Out:
# (3933, 36)

# %%
from sklearn.linear_model import LinearRegression

LinearRegression = LinearRegression()
LinearRegression.fit(mercedes_train.drop(columns='price'),mercedes_train['price'])
# Out:
# LinearRegression()

# %%
accuracy = LinearRegression.score(mercedes_test.drop(columns='price'),mercedes_test['price'])
print('Accuracy of model:',accuracy)
# Out:
# Accuracy: 0.776683654244062
